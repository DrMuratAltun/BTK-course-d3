# %% [markdown]
# ### Finans verilerini çekmek

# %%
#pip install yfinance #!pip install yfinance

# %%
import yfinance as yf

# %%
google=yf.Ticker('GOOGL')
df=google.history(period='1d', 
                  start='2023-1-1', end='2024-2-29')

# %%
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-01-03 00:00:00-05:00  89.589996  91.050003  88.519997  89.120003
# 2023-01-04 00:00:00-05:00  90.349998  90.650002  87.269997  88.080002
# 2023-01-05 00:00:00-05:00  87.470001  87.570000  85.900002  86.199997
# 2023-01-06 00:00:00-05:00  86.790001  87.690002  84.860001  87.339996
# 2023-01-09 00:00:00-05:00  88.360001  90.050003  87.860001  88.019997
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-01-03 00:00:00-05:00  28131200        0.0           0.0
# 2023-01-04 00:00:00-05:00  34854800        0.0           0.0
# 2023-01-05 00:00:00-05:00  27194400        0.0           0.0
# 2023-01-06 00:00:00-05:00  41381500        0.0           0.0
# 2023-01-09 00:00:00-05:00  29003900        0.0           0.0

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google=yf.Ticker('ERCB.IS')
df=google.history(period='1d', 
                  start='2023-1-1', end='2024-2-29')

# %%
df['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df=yf.download(["TSLA","AAPL","MSTF","AKBNK.IS"],
               start="2024-1-1", end="2024-2-29")
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
df.Close.plot();
